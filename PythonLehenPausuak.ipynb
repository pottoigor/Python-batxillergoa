# %% [markdown]
# ### **Python Programazioa**
#
# ***Instrukzio arruntak***
#
# Pantailan datuak erakusteko eta eskatzeko *print* eta *input* sententziak erabiltzen dira.

# %%
print ("Kaixo, nere lehen textua.")
izena = input ("Sartu zein den zure izena ")
print ("Nere izena " + izena)
# Out:
# Kaixo, nere lehen textua.
# Sartu zein den zure izenaIgor
# Nere izena Igor

# %% [markdown]
# Gogoratu *Input* eta *print*  sententziak beti string motako datuak idazten dituztela.
#
# Horretarako hurrengo funtzioak lagungarri izango zaizkizue:
#
# int()
# float()
# str()
#
# Hurrengo kodea zatia ejekutatzen baldin badugu, zer gertatzen da?

# %%
print ("nire urteak " + 5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-d02c6e35a740> in <module>()
# ----> 1 print ("nire urteak " + 5)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# Egizu zuzenketa, nola geratuko litzateke?

# %% [markdown]
# ***Baldintzak IF***
#
# if (baldintza):
# > print("baldintza")
#
# > print("bete da")
#
# else:*           *hautazkoa
# > print("baldintza ez da bete")
#
# ![baldintzaIF.JPG](data:image/jpeg;base64,...)

# %%
if(5>3):
  print ("baldintza 5>3")
  print ("bete da")
else:
  print ("baldintza ez da bete.")
# Out:
# baldintza 5>3
# bete da

# %% [markdown]
# Orain aldatu baldintza "5>3" eta jarri 5>9 baino, zer gertatuko da?
